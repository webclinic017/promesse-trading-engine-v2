# %%
import pandas as pd

# %%
trades = pd.read_csv('../backtest_results/trades.csv', header=0, parse_dates=True, index_col=0)

# %%
trades
# Out:
#        symbol  open_market_price  close_market_price  is_open   open_price  \
# 0    BTC-USDT            4313.56             4197.73    False  1000.000000
# 1    BTC-USDT            4173.00             4066.21    False   971.667609
# 2    BTC-USDT            4010.90             3918.80    False   945.363101
# 3    BTC-USDT            4027.05             3790.00    False   922.253505
# 4    BTC-USDT            3700.00             3500.80    False   866.622915
# ..        ...                ...                 ...      ...          ...
# 759  BTC-USDT           11624.10            11206.95    False    45.998316
# 760  BTC-USDT           11293.30            11011.70    False    44.279831
# 761  BTC-USDT           10854.10            10578.28    False    43.110116
# 762  BTC-USDT           10305.94             9950.00    False    41.950775
# 763  BTC-USDT            9909.98                 NaN     True    40.440067
#
# ...
