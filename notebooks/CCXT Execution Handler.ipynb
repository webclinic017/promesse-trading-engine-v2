# %%
import ccxt

# %%
exchange_class = getattr(ccxt, 'binance')
exchange = exchange_class({
    'apiKey': 'k1XUqP1PBJd0hBZJU0F9zvhnjgQBxjRLMQFS9m1bx7VhgSHL3TmwCbVE26t3Cig9',
    'secret': 'dlyMiklqANeCEwzgMHn3atqdVUl2YJsXhOLWZCGYdxX3eYMo5ggmh4VHsunGnbTf',
    'timeout': 30000,
    'enableRateLimit': True,
})

# %%
exchange.load_markets()
# Out:
# {'ETH/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 3, 'price': 6},
#   'limits': {'amount': {'min': 0.001, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'ETHBTC',
#   'symbol': 'ETH/BTC',
#   'base': 'ETH',
#   'quote': 'BTC',
#   'baseId': 'ETH',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'ETHBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '63100.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'LTC/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'LTCBTC',
#   'symbol': 'LTC/BTC',
#   'base': 'LTC',
#   'quote': 'BTC',
#   'baseId': 'LTC',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'LTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '72500.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'BNB/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 7},
#   'limits': {'amount': {'min': 0.01, 'max': 100000.0},
#    'price': {'min': 1e-07, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'BNBBTC',
#   'symbol': 'BNB/BTC',
#   'base': 'BNB',
#   'quote': 'BTC',
#   'baseId': 'BNB',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'BNBBTC',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1769700.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'NEO/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'NEOBTC',
#   'symbol': 'NEO/BTC',
#   'base': 'NEO',
#   'quote': 'BTC',
#   'baseId': 'NEO',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'NEOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'NEO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '365600.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'QTUM/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'QTUMETH',
#   'symbol': 'QTUM/ETH',
#   'base': 'QTUM',
#   'quote': 'ETH',
#   'baseId': 'QTUM',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'QTUMETH',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '146600.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'EOS/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'EOSETH',
#   'symbol': 'EOS/ETH',
#   'base': 'EOS',
#   'quote': 'ETH',
#   'baseId': 'EOS',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'EOSETH',
#    'status': 'TRADING',
#    'baseAsset': 'EOS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '286200.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'SNT/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'SNTETH',
#   'symbol': 'SNT/ETH',
#   'base': 'SNT',
#   'quote': 'ETH',
#   'baseId': 'SNT',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'SNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'SNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7648700.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'BNT/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'BNTETH',
#   'symbol': 'BNT/ETH',
#   'base': 'BNT',
#   'quote': 'ETH',
#   'baseId': 'BNT',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'BNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '356100.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'BCC/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 3, 'price': 6},
#   'limits': {'amount': {'min': 0.001, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'BCCBTC',
#   'symbol': 'BCC/BTC',
#   'base': 'BCC',
#   'quote': 'BTC',
#   'baseId': 'BCC',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'BCCBTC',
#    'status': 'BREAK',
#    'baseAsset': 'BCC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00100000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.00100000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': False},
#  'GAS/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 100000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'GASBTC',
#   'symbol': 'GAS/BTC',
#   'base': 'GAS',
#   'quote': 'BTC',
#   'baseId': 'GAS',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'GASBTC',
#    'status': 'TRADING',
#    'baseAsset': 'GAS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '100000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '111700.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'BNB/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'BNBETH',
#   'symbol': 'BNB/ETH',
#   'base': 'BNB',
#   'quote': 'ETH',
#   'baseId': 'BNB',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'BNBETH',
#    'status': 'TRADING',
#    'baseAsset': 'BNB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '68100.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'BTC/USDT': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 6, 'price': 2},
#   'limits': {'amount': {'min': 1e-06, 'max': 9000.0},
#    'price': {'min': 0.01, 'max': 1000000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'BTCUSDT',
#   'symbol': 'BTC/USDT',
#   'base': 'BTC',
#   'quote': 'USDT',
#   'baseId': 'BTC',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'BTCUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'BTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00000100',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00000100'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '3200.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'ETH/USDT': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 5, 'price': 2},
#   'limits': {'amount': {'min': 1e-05, 'max': 9000.0},
#    'price': {'min': 0.01, 'max': 1000000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'ETHUSDT',
#   'symbol': 'ETH/USDT',
#   'base': 'ETH',
#   'quote': 'USDT',
#   'baseId': 'ETH',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'ETHUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'ETH',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': True,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.01000000',
#      'maxPrice': '1000000.00000000',
#      'tickSize': '0.01000000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.00001000',
#      'maxQty': '9000.00000000',
#      'stepSize': '0.00001000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '52400.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'HSR/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 10000000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'HSRBTC',
#   'symbol': 'HSR/BTC',
#   'base': 'HSR',
#   'quote': 'BTC',
#   'baseId': 'HSR',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'HSRBTC',
#    'status': 'BREAK',
#    'baseAsset': 'HSR',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '10000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': False},
#  'OAX/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 0.0, 'max': None},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'OAXETH',
#   'symbol': 'OAX/ETH',
#   'base': 'OAX',
#   'quote': 'ETH',
#   'baseId': 'OAX',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'OAXETH',
#    'status': 'TRADING',
#    'baseAsset': 'OAX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000000',
#      'maxPrice': '0.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '822600.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'DNT/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'DNTETH',
#   'symbol': 'DNT/ETH',
#   'base': 'DNT',
#   'quote': 'ETH',
#   'baseId': 'DNT',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'DNTETH',
#    'status': 'TRADING',
#    'baseAsset': 'DNT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '7750800.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'MCO/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'MCOETH',
#   'symbol': 'MCO/ETH',
#   'base': 'MCO',
#   'quote': 'ETH',
#   'baseId': 'MCO',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'MCOETH',
#    'status': 'TRADING',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '29700.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'ICN/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 0.0, 'max': None},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'ICNETH',
#   'symbol': 'ICN/ETH',
#   'base': 'ICN',
#   'quote': 'ETH',
#   'baseId': 'ICN',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'ICNETH',
#    'status': 'BREAK',
#    'baseAsset': 'ICN',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': False,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000000',
#      'maxPrice': '0.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '1.3',
#      'multiplierDown': '0.7',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': False},
#  'MCO/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 10000000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'MCOBTC',
#   'symbol': 'MCO/BTC',
#   'base': 'MCO',
#   'quote': 'BTC',
#   'baseId': 'MCO',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'MCOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'MCO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '10000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '226300.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'WTC/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 7},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'WTCBTC',
#   'symbol': 'WTC/BTC',
#   'base': 'WTC',
#   'quote': 'BTC',
#   'baseId': 'WTC',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'WTCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1489800.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'WTC/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'WTCETH',
#   'symbol': 'WTC/ETH',
#   'base': 'WTC',
#   'quote': 'ETH',
#   'baseId': 'WTC',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'WTCETH',
#    'status': 'TRADING',
#    'baseAsset': 'WTC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '120000.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'LRC/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'LRCBTC',
#   'symbol': 'LRC/BTC',
#   'base': 'LRC',
#   'quote': 'BTC',
#   'baseId': 'LRC',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'LRCBTC',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '8481800.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'LRC/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'LRCETH',
#   'symbol': 'LRC/ETH',
#   'base': 'LRC',
#   'quote': 'ETH',
#   'baseId': 'LRC',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'LRCETH',
#    'status': 'TRADING',
#    'baseAsset': 'LRC',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '3072100.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'QTUM/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 10000000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'QTUMBTC',
#   'symbol': 'QTUM/BTC',
#   'base': 'QTUM',
#   'quote': 'BTC',
#   'baseId': 'QTUM',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'QTUMBTC',
#    'status': 'TRADING',
#    'baseAsset': 'QTUM',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '10000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '554400.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'YOYOW/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'YOYOBTC',
#   'symbol': 'YOYOW/BTC',
#   'base': 'YOYOW',
#   'quote': 'BTC',
#   'baseId': 'YOYO',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'YOYOBTC',
#    'status': 'TRADING',
#    'baseAsset': 'YOYO',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '41680800.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'OMG/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 10000000.0},
#    'price': {'min': 1e-06, 'max': 100000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'OMGBTC',
#   'symbol': 'OMG/BTC',
#   'base': 'OMG',
#   'quote': 'BTC',
#   'baseId': 'OMG',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'OMGBTC',
#    'status': 'TRADING',
#    'baseAsset': 'OMG',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '100000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '10000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '371100.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'OMG/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'OMGETH',
#   'symbol': 'OMG/ETH',
#   'base': 'OMG',
#   'quote': 'ETH',
#   'baseId': 'OMG',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'OMGETH',
#    'status': 'TRADING',
#    'baseAsset': 'OMG',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '372000.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'ZRX/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'ZRXBTC',
#   'symbol': 'ZRX/BTC',
#   'base': 'ZRX',
#   'quote': 'BTC',
#   'baseId': 'ZRX',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'ZRXBTC',
#    'status': 'TRADING',
#    'baseAsset': 'ZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '4510800.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'ZRX/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'ZRXETH',
#   'symbol': 'ZRX/ETH',
#   'base': 'ZRX',
#   'quote': 'ETH',
#   'baseId': 'ZRX',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'ZRXETH',
#    'status': 'TRADING',
#    'baseAsset': 'ZRX',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.01000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1617600.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'STRAT/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 7},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'STRATBTC',
#   'symbol': 'STRAT/BTC',
#   'base': 'STRAT',
#   'quote': 'BTC',
#   'baseId': 'STRAT',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'STRATBTC',
#    'status': 'TRADING',
#    'baseAsset': 'STRAT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MARKET_LOT_SIZE',
#      'minQty': '0.00000000',
#      'maxQty': '1022300.00000000',
#      'stepSize': '0.00000000'},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'STRAT/ETH': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 6},
#   'limits': {'amount': {'min': 0.01, 'max': 90000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.01, 'max': None}},
#   'id': 'STRATETH',
#   'symbol': 'STRAT/ETH',
#   'base': 'STRAT',
#   'quote': 'ETH',
#   'baseId': 'STRAT',
#   'quoteId': 'ETH',
#   'info': {'symbol': 'STRATETH',
#    'status': 'TRADING',
#    'baseAsset': 'STRAT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'ETH',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
# ...
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'ONT/USDC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 4},
#   'limits': {'amount': {'min': 0.01, 'max': 900000.0},
#    'price': {'min': 0.0001, 'max': 1000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'ONTUSDC',
#   'symbol': 'ONT/USDC',
#   'base': 'ONT',
#   'quote': 'USDC',
#   'baseId': 'ONT',
#   'quoteId': 'USDC',
#   'info': {'symbol': 'ONTUSDC',
#    'status': 'TRADING',
#    'baseAsset': 'ONT',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'WIN/BNB': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.1, 'max': None}},
#   'id': 'WINBNB',
#   'symbol': 'WIN/BNB',
#   'base': 'WIN',
#   'quote': 'BNB',
#   'baseId': 'WIN',
#   'quoteId': 'BNB',
#   'info': {'symbol': 'WINBNB',
#    'status': 'TRADING',
#    'baseAsset': 'WIN',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.10000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'WIN/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'WINBTC',
#   'symbol': 'WIN/BTC',
#   'base': 'WIN',
#   'quote': 'BTC',
#   'baseId': 'WIN',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'WINBTC',
#    'status': 'TRADING',
#    'baseAsset': 'WIN',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'WIN/USDT': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'WINUSDT',
#   'symbol': 'WIN/USDT',
#   'base': 'WIN',
#   'quote': 'USDT',
#   'baseId': 'WIN',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'WINUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'WIN',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'WIN/USDC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'WINUSDC',
#   'symbol': 'WIN/USDC',
#   'base': 'WIN',
#   'quote': 'USDC',
#   'baseId': 'WIN',
#   'quoteId': 'USDC',
#   'info': {'symbol': 'WINUSDC',
#    'status': 'TRADING',
#    'baseAsset': 'WIN',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'COS/BNB': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 6},
#   'limits': {'amount': {'min': 1.0, 'max': 9000000.0},
#    'price': {'min': 1e-06, 'max': 1000.0},
#    'cost': {'min': 0.1, 'max': None}},
#   'id': 'COSBNB',
#   'symbol': 'COS/BNB',
#   'base': 'COS',
#   'quote': 'BNB',
#   'baseId': 'COS',
#   'quoteId': 'BNB',
#   'info': {'symbol': 'COSBNB',
#    'status': 'TRADING',
#    'baseAsset': 'COS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BNB',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000100',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000100'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.10000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'COS/BTC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 8},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-08, 'max': 1000.0},
#    'cost': {'min': 0.0001, 'max': None}},
#   'id': 'COSBTC',
#   'symbol': 'COS/BTC',
#   'base': 'COS',
#   'quote': 'BTC',
#   'baseId': 'COS',
#   'quoteId': 'BTC',
#   'info': {'symbol': 'COSBTC',
#    'status': 'TRADING',
#    'baseAsset': 'COS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'BTC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000001',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000001'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '0.00010000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'COS/USDT': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 1, 'price': 5},
#   'limits': {'amount': {'min': 0.1, 'max': 9000000.0},
#    'price': {'min': 1e-05, 'max': 1000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'COSUSDT',
#   'symbol': 'COS/USDT',
#   'base': 'COS',
#   'quote': 'USDT',
#   'baseId': 'COS',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'COSUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'COS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00001000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00001000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.10000000',
#      'maxQty': '9000000.00000000',
#      'stepSize': '0.10000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'TUSDB/TUSD': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 2, 'price': 4},
#   'limits': {'amount': {'min': 0.01, 'max': 900000.0},
#    'price': {'min': 0.0001, 'max': 1000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'TUSDBTUSD',
#   'symbol': 'TUSDB/TUSD',
#   'base': 'TUSDB',
#   'quote': 'TUSD',
#   'baseId': 'TUSDB',
#   'quoteId': 'TUSD',
#   'info': {'symbol': 'TUSDBTUSD',
#    'status': 'TRADING',
#    'baseAsset': 'TUSDB',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'TUSD',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00010000',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00010000'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '0.01000000',
#      'maxQty': '900000.00000000',
#      'stepSize': '0.01000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'NPXS/USDT': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'NPXSUSDT',
#   'symbol': 'NPXS/USDT',
#   'base': 'NPXS',
#   'quote': 'USDT',
#   'baseId': 'NPXS',
#   'quoteId': 'USDT',
#   'info': {'symbol': 'NPXSUSDT',
#    'status': 'TRADING',
#    'baseAsset': 'NPXS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDT',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True},
#  'NPXS/USDC': {'percentage': True,
#   'tierBased': False,
#   'taker': 0.001,
#   'maker': 0.001,
#   'precision': {'base': 8, 'quote': 8, 'amount': 0, 'price': 7},
#   'limits': {'amount': {'min': 1.0, 'max': 90000000.0},
#    'price': {'min': 1e-07, 'max': 1000.0},
#    'cost': {'min': 10.0, 'max': None}},
#   'id': 'NPXSUSDC',
#   'symbol': 'NPXS/USDC',
#   'base': 'NPXS',
#   'quote': 'USDC',
#   'baseId': 'NPXS',
#   'quoteId': 'USDC',
#   'info': {'symbol': 'NPXSUSDC',
#    'status': 'TRADING',
#    'baseAsset': 'NPXS',
#    'baseAssetPrecision': 8,
#    'quoteAsset': 'USDC',
#    'quotePrecision': 8,
#    'orderTypes': ['LIMIT',
#     'LIMIT_MAKER',
#     'MARKET',
#     'STOP_LOSS_LIMIT',
#     'TAKE_PROFIT_LIMIT'],
#    'icebergAllowed': True,
#    'ocoAllowed': True,
#    'isSpotTradingAllowed': True,
#    'isMarginTradingAllowed': False,
#    'filters': [{'filterType': 'PRICE_FILTER',
#      'minPrice': '0.00000010',
#      'maxPrice': '1000.00000000',
#      'tickSize': '0.00000010'},
#     {'filterType': 'PERCENT_PRICE',
#      'multiplierUp': '5',
#      'multiplierDown': '0.2',
#      'avgPriceMins': 5},
#     {'filterType': 'LOT_SIZE',
#      'minQty': '1.00000000',
#      'maxQty': '90000000.00000000',
#      'stepSize': '1.00000000'},
#     {'filterType': 'MIN_NOTIONAL',
#      'minNotional': '10.00000000',
#      'applyToMarket': True,
#      'avgPriceMins': 5},
#     {'filterType': 'ICEBERG_PARTS', 'limit': 10},
#     {'filterType': 'MAX_NUM_ALGO_ORDERS', 'maxNumAlgoOrders': 5}]},
#   'active': True}}

# %%
exchange.fetch_orders('BTC/USDT')
# Out:
# [{'info': {'symbol': 'BTCUSDT',
#    'orderId': 518028738,
#    'orderListId': -1,
#    'clientOrderId': 'web_813b83fc138c478ca3b0c38be74ba4ae',
#    'price': '0.00000000',
#    'origQty': '0.00247700',
#    'executedQty': '0.00247700',
#    'cummulativeQuoteQty': '26.23774649',
#    'status': 'FILLED',
#    'timeInForce': 'GTC',
#    'type': 'MARKET',
#    'side': 'SELL',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': 1563212238022,
#    'updateTime': 1563212238022,
#    'isWorking': True},
#   'id': '518028738',
#   'timestamp': 1563212238022,
#   'datetime': '2019-07-15T17:37:18.022Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'BTC/USDT',
#   'type': 'market',
#   'side': 'sell',
#   'price': 10592.550056519984,
#   'amount': 0.002477,
#   'cost': 26.23774649,
#   'average': 10592.550056519984,
#   'filled': 0.002477,
#   'remaining': 0.0,
#   'status': 'closed',
#   'fee': None,
#   'trades': None},
#  {'info': {'symbol': 'BTCUSDT',
#    'orderId': 521161594,
#    'orderListId': -1,
#    'clientOrderId': 'web_1fe720c7c12849c1962e248347e0e17e',
#    'price': '0.00000000',
#    'origQty': '0.00258900',
#    'executedQty': '0.00258900',
#    'cummulativeQuoteQty': '26.20091301',
#    'status': 'FILLED',
#    'timeInForce': 'GTC',
#    'type': 'MARKET',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': 1563293719838,
#    'updateTime': 1563293719838,
#    'isWorking': True},
#   'id': '521161594',
#   'timestamp': 1563293719838,
#   'datetime': '2019-07-16T16:15:19.838Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'BTC/USDT',
#   'type': 'market',
#   'side': 'buy',
#   'price': 10120.09,
#   'amount': 0.002589,
#   'cost': 26.20091301,
#   'average': 10120.09,
#   'filled': 0.002589,
#   'remaining': 0.0,
#   'status': 'closed',
#   'fee': None,
#   'trades': None}]

# %%
exchange.has['createMarketOrder']
# Out:
# True

# %%
exchange.fetch_open_orders('BTC/USDT')
# Out:
# []
